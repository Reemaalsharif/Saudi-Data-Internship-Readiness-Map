# %%
import pandas as pd
import os

# %%
os.listdir()
# Out:
# ['.config', 'saudi_data_jobs_cleaned.csv', 'sample_data']

# %%
df = pd.read_csv("saudi_data_jobs_cleaned.csv")

df.head()
# Out:
#    job_id                               job_title  \
# 0       1                            Data Analyst
# 1       2               Geological Data Scientist
# 2       3                            Data Analyst
# 3       4  Analyst Pricing Analytics and Insights
# 4       5                      Power BI Developer
#
#                                company             city  \
# 0                      ALESAYI HOLDING           Jeddah
# 1        Maaden Barrick Copper Company  Mahd Adh Dhahab
# 2  PrimeGate for Communications and IT           Riyadh
# 3                   Schneider Electric     Saudi Arabia
# 4                 Acuative Middle East           Jeddah
#
#                       role_type         experience_level  \
# 0                  Data Analyst    Entry level / 3 years
# 1                Data Scientist  Entry level / 2-5 years
# 2                  Data Analyst              Entry level
# 3  Business / Pricing Analytics              Entry level
# ...

# %%
df.shape
# Out:
# (45, 15)

# %%
df.columns.tolist()
# Out:
# ['job_id',
#  'job_title',
#  'company',
#  'city',
#  'role_type',
#  'experience_level',
#  'skills',
#  'tools',
#  'source',
#  'job_link',
#  'date_collected',
#  'notes',
#  'city_cleaned',
#  'experience_category',
#  'role_category']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               45 non-null     int64
#  1   job_title            45 non-null     object
#  2   company              45 non-null     object
#  3   city                 45 non-null     object
#  4   role_type            45 non-null     object
#  5   experience_level     45 non-null     object
#  6   skills               45 non-null     object
#  7   tools                45 non-null     object
#  8   source               45 non-null     object
#  9   job_link             45 non-null     object
#  10  date_collected       45 non-null     object
#  11  notes                45 non-null     object
#  12  city_cleaned         45 non-null     object
#  13  experience_category  45 non-null     object
#  14  role_category        45 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# job_id                 0
# job_title              0
# company                0
# city                   0
# role_type              0
# experience_level       0
# skills                 0
# tools                  0
# source                 0
# job_link               0
# date_collected         0
# notes                  0
# city_cleaned           0
# experience_category    0
# role_category          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["role_category"].value_counts()
# Out:
# role_category
# AI                                8
# BI                                6
# Data Analysis                     5
# Data Science                      5
# Performance Analytics             5
# Governance                        4
# Business / Financial Analytics    3
# Fraud Analytics                   3
# Research Analytics                2
# Product Analytics                 1
# Marketing Analytics               1
# Internship / Training             1
# Other                             1
# Name: count, dtype: int64

# %%
df["experience_category"].value_counts()
# Out:
# experience_category
# Entry Level      18
# Mid-Level        13
# Not Specified    10
# Internship        3
# Senior            1
# Name: count, dtype: int64

# %%
df_powerbi = df.copy()

df_powerbi.head()
# Out:
#    job_id                               job_title  \
# 0       1                            Data Analyst
# 1       2               Geological Data Scientist
# 2       3                            Data Analyst
# 3       4  Analyst Pricing Analytics and Insights
# 4       5                      Power BI Developer
#
#                                company             city  \
# 0                      ALESAYI HOLDING           Jeddah
# 1        Maaden Barrick Copper Company  Mahd Adh Dhahab
# 2  PrimeGate for Communications and IT           Riyadh
# 3                   Schneider Electric     Saudi Arabia
# 4                 Acuative Middle East           Jeddah
#
#                       role_type         experience_level  \
# 0                  Data Analyst    Entry level / 3 years
# 1                Data Scientist  Entry level / 2-5 years
# 2                  Data Analyst              Entry level
# 3  Business / Pricing Analytics              Entry level
# ...

# %%
df_powerbi.to_csv("saudi_data_jobs_powerbi.csv", index=False)

# %%
os.listdir()
# Out:
# ['.config',
#  'saudi_data_jobs_cleaned.csv',
#  'saudi_data_jobs_powerbi.csv',
#  'sample_data']

# %%
df_powerbi.head()
# Out:
#    job_id                               job_title  \
# 0       1                            Data Analyst
# 1       2               Geological Data Scientist
# 2       3                            Data Analyst
# 3       4  Analyst Pricing Analytics and Insights
# 4       5                      Power BI Developer
#
#                                company             city  \
# 0                      ALESAYI HOLDING           Jeddah
# 1        Maaden Barrick Copper Company  Mahd Adh Dhahab
# 2  PrimeGate for Communications and IT           Riyadh
# 3                   Schneider Electric     Saudi Arabia
# 4                 Acuative Middle East           Jeddah
#
#                       role_type         experience_level  \
# 0                  Data Analyst    Entry level / 3 years
# 1                Data Scientist  Entry level / 2-5 years
# 2                  Data Analyst              Entry level
# 3  Business / Pricing Analytics              Entry level
# ...
